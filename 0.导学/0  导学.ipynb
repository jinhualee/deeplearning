# %% [markdown]
# # <b><center>Python深度学习实战 </center></b>

# %% [markdown]
# <b><center>主讲人：李进华博士 </center></b>

# %% [markdown]
# # 0 导学

# %% [markdown]
# - **目录**
#   - 0.1 教材和代码
#     - 0.1.1 教材与参考资料
#     - 0.1.2 代码
#   - 0.2 内容介绍
#     - 0.2.1 思维导图
#     - 0.2.2 课程特色
#   - 0.3 安装程序包
#     - 0.3.1 Python安装
#     - 0.3.2 jupyter-lab编程环境
#     - 0.3.3 Pytorch安装
#     - 0.3.4 d2l包

# %% [markdown]
# ## 0.1 教材和代码
# ### 0.1.1 教材与参考资料
# - 本视频课程以 **《动手学深度学习 Pytorch版》** 为骨干教材。感谢大神李沐，电子书籍免费开放。
# <br>下载地址：https://zh-v2.d2l.ai/d2l-zh-pytorch.pdf
# - 参考资料:**《深度学习》**花书、**《深度学习入门》**、**《Pytorch深度学习实战》**、**《fastai与python深度学习实践指南》** 、**《自然语言处理-基于预训练模型的方法》** 等。
# <center><img src='../img/0_1.png'></center>

# %% [markdown]
# ### 0.1.2 代码
# - 课程配套**注释版代码**下载地址：https://github.com/jinhualee/deeplearning
# - **原版代码**下载地址：https://zh.d2l.ai/   <br>
#
# ![image.png](attachment:91f14445-6890-4537-bdf1-89140a52ff4e.png)
# <br>
# - 解压Pytorch版
# ![image.png](attachment:7180f364-d545-4aea-a344-50b0f90e6c82.png)

# %% [markdown]
# ## 0.2 内容介绍

# %% [markdown]
# ### 0.2.1 思维导图
# <img src='../img/0_3.png' width=600px />

# %% [markdown]
# ### 0.2.2 课程特色
# - （1）**注释全面细致**
# ![image.png](attachment:c298ee6d-d090-417e-9b5b-a2a46d71fca1.png)
#
#
# - （2）对原教材的内容进行**更透彻的讲解**
# ![image.png](attachment:9ac0d69f-34eb-4977-a139-f6918e56edb6.png)
#
# - （3）补充深度学习涉及到的**基础编程知识**
# ![image.png](attachment:e97a9d26-95b2-4456-b084-c08d2d1b840b.png)
#
# - （4）解析深度学习中涉及到的**数据结构**
#
# ![image.png](attachment:d13fe4b4-cc57-460c-ba66-451110b5af00.png)
#
# - （5）图示与代码**对照解读**
# ![0_2.png](attachment:f757cd3a-991b-4ec3-a3b5-f586e61c0d86.png)

# %% [markdown]
# ## 0.3 安装程序包

# %% [markdown]
# ### 0.3.1 Python安装
#
# - python **3.11**版，下载双击安装即可，最好记住安装地址，后面有一些配置需要使用全路径来安装。
#   - Windows版：
#
#     - 下载地址：https://www.python.org/downloads/windows/
#       <img src='../img/0_4.png' />
#     - 设置镜像：
#       ![image.png](attachment:1297a790-5f29-49fa-b118-b76e3fbed1c7.png)
#     - 安装必要的包：
#       ![image.png](attachment:0e148e7d-be23-4152-9d8e-8a8522f1fac4.png)
#   - Linux版：
#     - 以ubuntu为例：
#     <img src='../img/0_5.png' />
#
#       - 注意：在ubuntu上安装Python稍显复杂，上述命令在你的Linux环境下可能无法正确安装。
#       - 本课程的前端课程《Python编程与数学基础》将详细讲解安装过程。
#     - 安装pip：
#     ![image.png](attachment:c62ca8b9-a266-421a-8e4e-c9b8c22dfbc3.png)
#
#     - 设置**pip镜像**，在当前登录用户的HOME目录下生成一个名为<b>.pip文件夹</b>:mkdir .pip, 然后进入该文件夹使用vi命令编辑一个名为<b>pip.conf</b>的文件，往该文件里填入如下内容：
#     ![image.png](attachment:f9507118-bf2f-4a9d-aa61-f2e3f376521d.png)
#
#     - 安装必要的包：
#     ![image.png](attachment:95d49137-e8c0-43fa-a4f2-bea7bf1bca91.png)
#
#
#
# - 本课程使用的是Windows+Linux平台，大部分代码都是运行在Windows平台下。
#   - 本课程后面若干章内容涉及到计算机视觉(CV)和自然语言处理(NLP)，一些复杂模型比如BERT,llama2等，则在Linux环境下的GPU上运行。
#
# - 本课程部分代码运行平台包括两张英伟达GPU：一张是3090ti, 24G显存；一张是A800,80G显存。
#   - 按照[李沐的测试](https://www.bilibili.com/video/BV1LT411F77M/?spm_id_from=333.999.0.0&vd_source=f229b48b5ab83786d3217870304efe4d])，3090ti在torch.float32数据类型的矩阵乘法运算速度可以达到<b>40TFLOPS</b>以上，torch.float16数据类型可以达到<b>80TFLOPS</b>以上。
#   - **TFLOPS** 是Tera Floating Point Operations Per Second的缩写，表示每秒钟可以进行的浮点运算次数，单位为万亿次（Tera计为10的12次方）。它是衡量GPU（图形处理单元）或CPU（中央处理单元）计算性能的一个指标。

# %% [markdown]
# ### 0.3.2 jupyter-lab编程环境
# - 安装**jupyter-lab**，Windows与Linux平台上安装命令相同，即: pip install jupyterlab
#   ![image.png](attachment:9162a94b-98f5-4b88-88b0-ccd958f0fa49.png)
# - Windows平台上可以直接在命令行运行jupyter-lab命令，即可打开运行环境
#   ![image.png](attachment:acc91adb-f85f-4b98-8ee4-e19f4fde787a.png)
#   ![image.png](attachment:1af72cf3-e744-4674-9f61-18fb9d3d2518.png)
# - Linux(Ubuntu)
#   - 运行：$HOME/.local/bin/juypter-lab，即可打开
#   - 如需直接运行，即不加上路径，则需要修改/etc/profile,将.local/bin路径加入**PATH参数**中。然后<b><font color=red>重启系统</font>：
#     ![image.png](attachment:8cffbaca-fccc-4da6-a185-44f58203b710.png)
#     <img src='../img/0_2.png' />
#   - 直接运行jupyter-lab命令：
#     ![image.png](attachment:73e99182-82a4-416f-bcd6-f45ef47bc173.png)
#     ![image.png](attachment:a083d17b-3651-4b47-be55-eb6ca52e7b82.png)

# %% [markdown]
# ### 0.3.3 Pytorch安装
# - 下载网址：https://pytorch.org/
#   ![image.png](attachment:220e9e06-6816-4381-9d7d-625bda9f0469.png)
#
# - GPU版Pytorch及其附带包有2.6G，安装需要花点时间，耐心等待:
#   <img src='../img/0_6.png' />
#
# - Linux版本的Pytorch安装过程类似

# %%
# pytorch cuda版安装成功
import torch
torch.__version__
# Out:
# '2.1.2+cu121'

# %%
# NVIDIA的GPU驱动程序安装将另行发布专题视频课程
# !nvidia-smi
# Out:
# Fri Apr 26 17:45:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.26                 Driver Version: 546.26       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce MX250         WDDM  | 00000000:02:00.0 Off |                  N/A |
# | N/A   55C    P0              N/A / ERR! |      0MiB /  2048MiB |      2%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# ### 0.3.4 d2l包
# - d2l是《动手学深度学习》的工具包，教材的源代码中有很多地方都需要调用该包的功能。
# - 安装软件包(**尽量不要安装依赖包**)：pip install --no-dependencies d2l
# - 如果不想安装，可以将d2l的源代码放在示例代码**相同路径**下，直接import后使用。
# - **本课程对d2l包的部分代码有所修改**，主要是确保代码在windows和linux平台上都能运行，**请留意!**

# %%
import d2l
d2l.__version__
# Out:
# '0.17.6'

# %%
# pandas, numpy, sklearn
import pandas as pd
import numpy as np
import sklearn
pd.__version__, np.__version__, sklearn.__version__
# Out:
# ('2.1.4', '1.26.2', '1.2.2')

# %%
print(d2l.__doc__)
# Out:
# Saved source code for "Dive into Deep Learning" (https://d2l.ai).
#
# Please import d2l by one of the following ways:
#
# from d2l import mxnet as d2l  # Use MXNet as the backend
# from d2l import torch as d2l  # Use PyTorch as the backend
# from d2l import tensorflow as d2l  # Use TensorFlow as the backend
# from d2l import jax as d2l  # Use Jax as the backend
